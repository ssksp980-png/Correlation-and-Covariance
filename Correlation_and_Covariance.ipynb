# %% [markdown]
# **Correlation and Covariance**

# %% [markdown]
# 1   . efine Covariance and explain how it differs from Correlation
#        in terms of scale and interpretation.
#
# Ans  - covaeiance measure how much two variable change together .if the
#        covariance is positive .if its negative when one increase the other
#        tends to decrease.
#        covariance - scale dependent indicates direction of relationship
#        correlation - scale dependent indicates direction and strengh of relationship between -1and 1.
#
# 2   .  What does a positive, negative, and zero covariance indicate
#        about the relationship between two variables?
#
# Ans  - positive covariance- when one variable increases the other tends to
#        increase too.variables move together in the same direction.
#       negative covariance - when one variable increases the other tends to
#       decreases variable move in possitive direction.
#       Zero covariance - theres no liner relationship between the variables
#       change in one variable dont tend to associate with change in the other.
#
# 3   .  Discuss the limitations of covariance as a measure of relationship
#        between two variables. Why is correlation preferred in many cases?
#
# Ans  - covariance tells us about the dorection of the liner relationship
#        between two variables .if covarience is possitive the variable tend to increse toughter covariance has limitations
#        scale dependancy- covarience value depends on the scale of the variables.
#        no bounded measure- covarience doesnot give a standardized measure relationship strength.
#
#
# 4   .  Explain the difference between Pearson’s correlation coefficient
#         and Spearman’s rank correlation coefficient. When would you prefer to use Spearman’s correlation?
#
#
# Ans  - pearsons correlation coefficent and spearmans rank correlation
#        coefficient are both mearsues of correlation between two variable .
#        pearsons correlation coefficient- monotonic relationship beyween
#        two variable based on their rank .
#        use case - when dealing with ordinal data or when the relationshipis not liner but is monotonic.
#
#
# 5   .  If the correlation coefficient between two variables X and Y
#         is 0.85, interpret this value in context. Can you infer causation from this value? Why or why not?
#
#
# Ans  - A correlation coefficent of 0.85 between varible X and Y indicates a
#        strong positive liner relationship between the two variable the means that as X increase Y tends to increse as well and the relationship is fairly cosistent.
#
# 6    . infer causation from this value? Why or why not?
#
#
# Ans   - X =(2+4+6+8)/4=20/4=5
#         Y=Z(3+7+5+10)25/4=6.25
#         deviations from the mean X and Y
#         X=(2-5,4-5,6-5,8-5) = -3,-1,1,3
#         Y=(3-6.25,7-6.25,5-6.25,10-6.25)= -3.25,0.75,-1.25,3.25
#         product of the divisions =-0.75 and 11.25
#         =9.75-0.75-1.25+11.25=19
#         here n=4
#         (n-1)= 19/4-1=19/3=6.33
#
# 7    . The following table shows heights (in cm) and weights (in kg) of 5
#        students.Find the correlation coefficient between Height and Weight.
#
#
# Ans  - height (cm)=150+160+165+170+180/5=165cm
#        weight (kg) =50+55+58+62+72/5=59kg
#        sum of the products =335
#        deviations og hight and weight
#        sum of squares for height=500
#        sum of squares for weight=228
#        pearson correlation coefficient=0.992
#
# 8    .  Given the dataset below, determine whether there is a positive or
#         negative  correlation between X and Y.(No need for exact calculation, just reasoning.)
#
#
# Ans   - As X increases from 1 to 5 ,Y decreases from 15 to 3 this indicates
#         that as one variable increases the other decreases . so there a negative correlation between X and Y.
#
# 9    . Two investment portfolios have the following returns (%) over 5
#        years.Compute the covariance and correlation coefficient, and interpret whether the portfolios move together.
#
#
# Ans   - A = 8+10+12+9+11/5=50/5=10
#         B = 6+9+11+8+10/5=44/5=8.8
#         calculate the covariance=
#         year 1 =5.6
#         year 2= 0
#         year 3= 4.4
#         year 4 = 0.8
#         year 5= 1.2
#         sum = 12/5-1=12/4=3
#         varience A = 1.581
#         varience B =1.924
#         =3/1.581*1.924=3/3.042=0.986
